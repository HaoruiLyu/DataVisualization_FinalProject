# %% [markdown]
# ## Data Cleaning
# Since the source data set is too large, we intercepted the flight data in 2022 for analysis and visualization.

# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\PersonalFiles\IS445\FinalProject\flights_sample_3m.csv")
data['year'] = pd.to_datetime(data['FL_DATE']).dt.year
data2023 = data[data['year'] == 2023]
data2023 = data2023.drop(['AIRLINE_DOT', 'DOT_CODE', 'year'], axis=1)
data2023
# Out:
#             FL_DATE                 AIRLINE AIRLINE_CODE  FL_NUMBER ORIGIN  \
# 3        2023-03-06    Delta Air Lines Inc.           DL       2295    MSP
# 6        2023-06-11  American Airlines Inc.           AA       2134    DCA
# 8        2023-02-12        Spirit Air Lines           NK        590    IAH
# 29       2023-04-15        Republic Airline           YX       3615    MSP
# 30       2023-01-03           Allegiant Air           G4       1206    USA
# ...             ...                     ...          ...        ...    ...
# 2999976  2023-03-13  Southwest Airlines Co.           WN       3197    OAK
# 2999980  2023-04-23    Delta Air Lines Inc.           DL       1208    ORD
# 2999982  2023-01-03  American Airlines Inc.           AA       1456    SLC
# 2999989  2023-05-29        Republic Airline           YX       4644    PWM
# 2999990  2023-07-26   SkyWest Airlines Inc.           OO       4126    DTW
#
# ...

# %%
data2023.to_csv(r'D:\PersonalFiles\IS445\FinalProject\data_2023.csv', index=False)
